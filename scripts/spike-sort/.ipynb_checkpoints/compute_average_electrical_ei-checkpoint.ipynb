# %%
from scipy.io import loadmat
import matplotlib.pyplot as plt
import os
import re
from src.bootstrap_error_analysis import *
from src.run_gsort_v2_wuericmod import get_vision_data

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
file = "/Volumes/Scratch/Users/jeffbrown/final_tests2/2016-06-13-0/data001/kilosort_data000/data000/gsort_full_data_tensor.mat"

# %%
loaded_data = loadmat(file)

# %%
loaded_data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'cells', 'gsorted_cells', 'probs', 'filtered_probs', 'run'])

# %%
sorted_cells = loaded_data['gsorted_cells'].flatten()
cells = loaded_data['cells'].flatten()
run = loaded_data['run']

# %%
# for cell_index in range(len(sorted_cells)):
cell_index = 0
for i, sig in enumerate(loaded_data['filtered_probs'][sorted_cells[cell_index]]):
    if run[sorted_cells[cell_index]][i]:
        plt.figure()
        ax = plt.subplot(111)
        ax.set_title(f"cell={cells[sorted_cells[cell_index]]},pattern={i+1}")
        ax.plot(sig, '-o');
        ax.set_ylim([0,1])

# %%
# for cell_index in range(len(sorted_cells)):
p = 8
cell_index = 0
for i, sig in enumerate(loaded_data['filtered_probs'][:,p-1,:]):
    if run[i, p-1]:
        plt.figure()
        ax = plt.subplot(111)
        ax.set_title(f"cell={cells[i]},pattern={p}")
        ax.plot(sig, '-o');
        ax.set_ylim([0,1])

# %%
ANALYSIS_BASE = "/Volumes/Analysis/"
gsort_path = "/Volumes/Scratch/Users/jeffbrown/final_tests2/"
dataset = "2016-06-13-0"
estim = "data001"
wnoise = "kilosort_data000/data000"
thr_factor = 1
n = 4
ps = [int(re.findall('\d+', m)[-1]) for m in os.listdir(os.path.join(gsort_path, dataset, estim,wnoise)) if (len(re.findall('\d+', m))==2) and (f"_n{n}_" in m)]

vcd = get_vision_data(ANALYSIS_BASE, dataset, wnoise)
noise = vcd.channel_noise




pattern_movies, total_probs, edge_probs, clusters, edges, electrodes,num_trials = get_bootstrap_information(ANALYSIS_BASE, gsort_path,dataset, estim, wnoise, ps,n, electrodes_stored = True)

dss, dss_stack, dss_inds, num_electrodes, num_samples, movie_stack= get_difference_signals(pattern_movies,clusters,edges,ANALYSIS_BASE, dataset, estim, electrodes)
average_ds, average_error,std_error, shifted_dss, shifted_dss_stack,error, error_stack = compute_average_diff_signal_and_error(dss,dss_stack, num_electrodes, num_samples)
# Out:
# 6it [00:00, 713.32it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 236/236 [00:02<00:00, 82.86it/s]

# %%
test_set = [i for i in range(len(electrodes))]
electrode = 0
factor =0
exp_error = np.array([np.sqrt(num_samples*2*(2*noise[e])**2) for e in electrodes])
# exp_error = np.array([16*noise[e] for e in electrodes])


new_instance_probs = get_instance_modified_edge_probs(edge_probs, error, dss_inds, exp_error, std_error, factor, test_set,num_trials)

# %%
pattern_movies_array = np.array(pattern_movies)
for p in set(pattern_movies_array[:,0]):
    probs = new_instance_probs[ pattern_movies_array[:,0]==p]
    
    plt.figure()
    ax = plt.subplot(111)
    ax.set_title(p)
    old_probs = loaded_data['filtered_probs'][list(cells).index(n)][p-1]
    ax.plot(old_probs, '-o')
    ax.plot(probs, '-o');

    ax.set_ylim([0,1])

# %%
n
# Out:
# 96

# %%
for i in [i for i in np.argwhere(pattern_movies_array[:,0]==16).flatten()]:
    ds = shifted_dss[i]
    plt.figure()
    
    ax1 = plt.subplot(211)
    ax2 = plt.subplot(212)
    for ss, s in enumerate(ds):
        good_spikes = np.all(error[i][ss] < exp_error, axis = 1)
        ax1.plot(s.reshape((s.shape[0],-1))[good_spikes].T, color = f"C{ss%10}")
        ax2.plot(s.reshape((s.shape[0],-1))[~good_spikes].T, color = f"C{ss%10}")
        
    ax1.plot(average_ds.flatten(), color = "black")
    ax1.set_title(pattern_movies_array[:,1][i])
    ax2.plot(average_ds.flatten(), color = "black")
# Out:
# /tmp/ipykernel_16769/3285426387.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()

# %%
ax = plt.subplot(111)
ax.plot(average_ds.flatten())
ax.plot(vcd.get_ei_for_cell(n).ei[electrodes, :55].flatten())

# %%
electrodes
# Out:
# [73, 82, 77]
